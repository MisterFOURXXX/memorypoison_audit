# %%
# %% [markdown]
# # 00 – Master Environment Check

# %% 
import sys, torch, chromadb, sklearn, sentence_transformers
import memorypoison_audit.source.disable_warnings
print(f"Python: {sys.version}")
print(f"Torch: {torch.__version__}")
print(f"CUDA Available: {torch.cuda.is_available()}")

# %%
from memorypoison_audit.core.memory_store import MemoryStore
import yaml
try:
    with open("configs/attack_config.yaml", "r") as f:
        config = yaml.safe_load(f)
    print("Configs loaded successfully.")
except Exception as e:
    print(f"Config load error: {e}")

# %%
try:
    store = MemoryStore()
    print("MemoryStore initialized successfully.")
    print("All checks passed.")
except Exception as e:
    print(f"MemoryStore initialization failed: {e}")
